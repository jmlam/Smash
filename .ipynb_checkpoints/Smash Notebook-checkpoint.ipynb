# %%
import requests as re
import json

# %%
resp = re.get('https://api.kuroganehammer.com/api/characterattributes')

# %%
resp.json()
# Out:
# [{'InstanceId': 'cf32fbe9f4f94cf88f92dde8118e77a9',
#   'Name': 'AerialJump',
#   'OwnerId': 1,
#   'Owner': 'Bayonetta',
#   'Values': [{'Value': '42',
#     'Owner': 'Bayonetta',
#     'OwnerId': 1,
#     'Name': 'HEIGHT'}],
#   'Game': 'Smash4',
#   'Related': {'Smash4': {'Character': 'http://api.kuroganehammer.com/api/characters/name/Bayonetta?game=smash4',
#     'Self': 'http://api.kuroganehammer.com/api/characterattributes/cf32fbe9f4f94cf88f92dde8118e77a9?game=smash4'},
#    'Ultimate': {'Character': 'http://api.kuroganehammer.com/api/characters/name/Bayonetta?game=ultimate'}},
#   'Links': [{'Rel': 'self',
#     'Href': 'http://api.kuroganehammer.com/api/characterattributes/cf32fbe9f4f94cf88f92dde8118e77a9?game=smash4'},
#    {'Rel': 'character',
#     'Href': 'http://api.kuroganehammer.com/api/characters/name/Bayonetta?game=smash4'}]},
#  {'InstanceId': 'e23ba83137ad4e669e469f1ce2e16ad0',
#   'Name': 'AirAcceleration',
#   'OwnerId': 1,
#   'Owner': 'Bayonetta',
# ...
